# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
data = pd.read_csv("C:/Users/umaac/Downloads/instagramdata.csv",encoding='latin1')
data
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# ...

# %%
data.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
data.tail()
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 114         2      38    373              73       80
# 115         4       1    148              20       18
# 116         0       1     92              34       10
# 117         2      75    549             148      214
# 118         5      26    443             611      228
#
#                                                Caption  \
# 114  Here are some of the best data science certifi...
# 115  Clustering is a machine learning technique use...
# ...

# %%
data.describe()
# Out:
#         Impressions     From Home  From Hashtags  From Explore   From Other  \
# count    119.000000    119.000000     119.000000    119.000000   119.000000
# mean    5703.991597   2475.789916    1887.512605   1078.100840   171.092437
# std     4843.780105   1489.386348    1884.361443   2613.026132   289.431031
# min     1941.000000   1133.000000     116.000000      0.000000     9.000000
# 25%     3467.000000   1945.000000     726.000000    157.500000    38.000000
# 50%     4289.000000   2207.000000    1278.000000    326.000000    74.000000
# 75%     6138.000000   2602.500000    2363.500000    689.500000   196.000000
# max    36919.000000  13473.000000   11817.000000  17414.000000  2547.000000
#
#              Saves    Comments      Shares       Likes  Profile Visits  \
# count   119.000000  119.000000  119.000000  119.000000      119.000000
# mean    153.310924    6.663866    9.361345  173.781513       50.621849
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %%
data.shape
# Out:
# (119, 13)

# %%
list(data)
# Out:
# ['Impressions',
#  'From Home',
#  'From Hashtags',
#  'From Explore',
#  'From Other',
#  'Saves',
#  'Comments',
#  'Shares',
#  'Likes',
#  'Profile Visits',
#  'Follows',
#  'Caption',
#  'Hashtags']

# %%
data.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
data1=data.drop(['From Home','From Hashtags','From Explore','From Other','Caption','Hashtags'],axis=1)
data1
# Out:
#      Impressions  Saves  Comments  Shares  Likes  Profile Visits  Follows
# 0           3920     98         9       5    162              35        2
# 1           5394    194         7      14    224              48       10
# 2           4021     41        11       1    131              62       12
# 3           4528    172        10       7    213              23        8
# 4           2518     96         5       4    123               8        0
# ..           ...    ...       ...     ...    ...             ...      ...
# 114        13700    573         2      38    373              73       80
# 115         5731    135         4       1    148              20       18
# 116         4139     36         0       1     92              34       10
# 117        32695   1095         2      75    549             148      214
# 118        36919    653         5      26    443             611      228
#
# [119 rows x 7 columns]

# %%
data1['Impressions'].unique()
# Out:
# array([ 3920,  5394,  4021,  4528,  2518,  3884,  2621,  3541,  3749,
#         4115,  2218,  3234,  4344,  3216,  9453,  5055,  4002,  3169,
#         6168,  2407,  2064,  3973,  7281,  3052,  4628,  4082,  2766,
#         3924,  3015,  6666,  3854,  4355,  4343,  6108,  2523,  2327,
#         3990,  2191,  1941, 16062,  4998,  4289,  3880,  3786,  4298,
#         3630,  2826,  7407, 10386,  2998,  7018,  2941,  6432, 10667,
#         3988,  4978,  3388,  4467,  3246,  5072,  6339,  4239,  3454,
#         7571,  3333,  3818, 10933,  5058,  3601,  3480,  3525,  3606,
#         5542,  6559,  3623, 10493,  4446,  2957,  5538,  4681,  5273,
#         5409,  5323,  8001,  4150,  4609,  6348, 11068,  7231, 17396,
#         6814, 17713,  5563,  4842, 11149, 10206, 13700,  5731,  4139,
#        32695, 36919], dtype=int64)

# %%
dataage=data1.groupby(['Impressions']).sum()
dataage.tail(20)
# Out:
#              Saves  Comments  Shares  Likes  Profile Visits  Follows
# Impressions
# 7018           342         9      16    236              20       12
# 7231            73         8       3    171              74       26
# 7281           167         7       9    195             144      100
# 7407           576        10      30    526              78       36
# 7571           421         7      12    269              50       46
# 8001            83         8       7    203              92       14
# 9453           100         6      10    294             181       42
# 10206          182        10      17    172             237      100
# 10386         1336        16      82    656              84       76
# 10493           99         9       1    244             155       32
# 10667          219        13      15    297             306       74
# 10933          225        13      15    301             347       94
# ...

# %%
y=data1['Impressions']
x=data1.drop('Impressions',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
classifier=LinearRegression()
classifier.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x
# Out:
#      Saves  Comments  Shares  Likes  Profile Visits  Follows
# 0       98         9       5    162              35        2
# 1      194         7      14    224              48       10
# 2       41        11       1    131              62       12
# 3      172        10       7    213              23        8
# 4       96         5       4    123               8        0
# ..     ...       ...     ...    ...             ...      ...
# 114    573         2      38    373              73       80
# 115    135         4       1    148              20       18
# 116     36         0       1     92              34       10
# 117   1095         2      75    549             148      214
# 118    653         5      26    443             611      228
#
# [119 rows x 6 columns]

# %%
y
# Out:
# 0       3920
# 1       5394
# 2       4021
# 3       4528
# 4       2518
#        ...
# 114    13700
# 115     5731
# 116     4139
# 117    32695
# 118    36919
# Name: Impressions, Length: 119, dtype: int64

# %%
ypred=classifier.predict(x_test)
ypred
# Out:
# array([ 4956.53898672,  8013.43236672,  3606.94166553,  6470.82102557,
#         3206.78220259, 25438.51106329,  4321.437576  ,  2742.85396499,
#        13366.49624876,  3739.26041408,  5376.31064181,  8698.33966607,
#         3576.91713218,  2292.65078372,  4214.65989177,  2534.4963345 ,
#         3899.87034729,  4090.48065433,  4213.90305029,  5113.00905561,
#        10797.31428899, 15876.60585672,  3206.78220259,  6243.89509025,
#         4519.95991088,  3702.29462844,  3656.2486316 ,  4203.2775734 ,
#         9857.94925064,  4462.99776294,  4629.15756298,  9292.91798776,
#         2797.68348691,  3853.92082209,  7246.84814058,  5032.09276956])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)
# Out:
# 0.8721185830964757

# %%
cor_mat=data1.corr()
cor_mat
# Out:
#                 Impressions     Saves  Comments    Shares     Likes  \
# Impressions        1.000000  0.779231 -0.028524  0.634675  0.849835
# Saves              0.779231  1.000000 -0.026912  0.860324  0.845643
# Comments          -0.028524 -0.026912  1.000000  0.016933  0.123586
# Shares             0.634675  0.860324  0.016933  1.000000  0.707794
# Likes              0.849835  0.845643  0.123586  0.707794  1.000000
# Profile Visits     0.760981  0.360628  0.096714  0.245361  0.626107
# Follows            0.889363  0.628461 -0.060631  0.493070  0.746333
#
#                 Profile Visits   Follows
# Impressions           0.760981  0.889363
# Saves                 0.360628  0.628461
# Comments              0.096714 -0.060631
# Shares                0.245361  0.493070
# Likes                 0.626107  0.746333
# Profile Visits        1.000000  0.853152
# Follows               0.853152  1.000000

# %%
Results=pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=ypred
Results=Results.reset_index()
Results['ID']=Results.index
Results.head(15)
# Out:
#     index  Actual     Predicted  ID
# 0      56    4978   4956.538987   0
# 1      89    7407   8013.432367   1
# 2       4    2518   3606.941666   2
# 3      45    4298   6470.821026   3
# 4      26    5394   3206.782203   4
# 5     117   32695  25438.511063   5
# 6      69    3601   4321.437576   6
# 7      10    2218   2742.853965   7
# 8      90   10386  13366.496249   8
# 9      73    5542   3739.260414   9
# 10     18    6168   5376.310642  10
# 11    112   11149   8698.339666  11
# 12     11    3234   3576.917132  12
# 13     96    2766   2292.650784  13
# 14     42    4289   4214.659892  14

# %%
sns.lineplot(x='ID',y='Actual',data=Results.head(50))
sns.lineplot(x='ID',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %%
sns.lineplot(x='ID',y='Actual',data=Results.head(50))
sns.lineplot(x='ID',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %%
sns.heatmap(cor_mat,vmax=1,vmin=0,annot=True,linewidths=5,cmap='bwr')
# Out:
# <Axes: >

# %% [markdown]
# # Elastic Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
elastic = ElasticNet()
parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]}
elastic_regressor = GridSearchCV(elastic, parameters)
elastic_regressor.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=ElasticNet(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20]})

# %%
elastic_regressor.best_params_
# Out:
# {'alpha': 20}

# %%
elastic=ElasticNet(alpha=20)
elastic.fit(x_train,y_train)
y_pred_elastic=elastic.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_elastic)
# Out:
# 0.8812157873761425

# %%
from sklearn.metrics import mean_squared_error
elastic_Error=mean_squared_error(y_pred_elastic,y_test)
elastic_Error
# Out:
# 3259527.421627713

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred_elastic
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index  Actual     Predicted  Id
# 0     56    4978   4975.790957   0
# 1     89    7407   7853.172792   1
# 2      4    2518   3534.251763   2
# 3     45    4298   6429.366015   3
# 4     26    5394   3809.643297   4
# 5    117   32695  25726.980017   5
# 6     69    3601   4027.067918   6
# 7     10    2218   2776.761070   7
# 8     90   10386  13508.657911   8
# 9     73    5542   3816.270099   9

# %%
sns.lineplot(x='Id',y='Actual',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import GridSearchCV #GridSearchCV is for parameter tuning
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()
n_estimators=[25,50,75,100,125,150,175,200] #number of decision trees in the forest, default = 100
criterion=['squared_error'] #criteria for choosing nodes default = 'gini'
max_depth=[3,5,10] #maximum number of nodes in a tree default = None (it will go till all possible nodes)
parameters={'n_estimators': n_estimators,'criterion':criterion,'max_depth':max_depth}  
RFC_reg = GridSearchCV(reg, parameters)
RFC_reg.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error'],
#                          'max_depth': [3, 5, 10],
#                          'n_estimators': [25, 50, 75, 100, 125, 150, 175, 200]})

# %%
RFC_reg.best_params_
# Out:
# {'criterion': 'squared_error', 'max_depth': 10, 'n_estimators': 100}

# %%
reg=RandomForestRegressor(n_estimators=150,criterion='squared_error',max_depth=5)
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=150)

# %%
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([ 4759.21743019,  6533.88404294,  3354.50394294,  4822.30658842,
#         4547.24246454, 25092.74666667,  3816.14346857,  2613.22082761,
#        13001.68183639,  4278.07473536,  5976.21018953, 11706.76783232,
#         4197.46781288,  3212.98861538,  5443.57664549,  4170.12252298,
#         3214.39791621,  4332.54292653,  4084.20216624,  5533.03871939,
#        10986.01171062, 15945.84266667,  4547.24246454,  4639.26042304,
#         4486.26940656,  4292.16824155,  4447.18877198,  3420.32352329,
#         6639.81696519,  4496.74877374,  3503.40627161, 12041.74633333,
#         2610.82480736,  3438.34567964,  5890.05236693,  6589.06218661])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8863735758386838

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index  Actual     Predicted  Id
# 0     56    4978   4759.217430   0
# 1     89    7407   6533.884043   1
# 2      4    2518   3354.503943   2
# 3     45    4298   4822.306588   3
# 4     26    5394   4547.242465   4
# 5    117   32695  25092.746667   5
# 6     69    3601   3816.143469   6
# 7     10    2218   2613.220828   7
# 8     90   10386  13001.681836   8
# 9     73    5542   4278.074735   9

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='Id',y='Actual',data=Results.head(100))
sns.lineplot(x='Id',y='Predicted',data=Results.head(100))
plt.plot()
# Out:
# []
